# %% [markdown]
# # **TECHNIKI PROGRAMOWANIA - PROJEKT 3**
#
#
#
# #### Zofia Narloch 198232
# #### Aleksandra Słomska

# %% [markdown]
# Wykorzystane biblioteki:
# - matploplusplus
# - audioFile

# %% [markdown]
# ## 1. Wizualizacja sygnału z wykorzystaniem biblioteki matplotplusplus

# %%
import scikit_build_example as az
az.plot()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Przykład wizualizacji sygnału dla sygnału audio

# %%
import scikit_build_example as az
az.visualize_audio("C:/ZOSIA/Studia/projekt_sygnaly/examples_test-audio.wav")

# %% [markdown]
# ![image.png](attachment:eddbb02f-6ec6-41f0-9ceb-6ee0eb469c93.png)

# %% [markdown]
# ## 2. Generowanie sygnałów o zadanej częstotliwości (sin, cos, prostokątny, piłokształtny)

# %% [markdown]
# ###  - SINUS
#
# Generowanie wykresu sinusa o zadanej częstotliwości

# %%
import scikit_build_example as az
f = 5
az.generate_sine_wave(f)

# %% [markdown]
# ![image.png](attachment:347f4012-a844-4e6d-91bb-df93f67f839a.png)

# %% [markdown]
# ###  - COSINUS
#
# Generowanie wykresu cosinusa o zadanej częstotliwości

# %%
import scikit_build_example as az
f = 5
az.generate_cosine_wave(f)

# %% [markdown]
# ![image.png](attachment:81069e72-7e9c-478c-a990-8d9de119b4e9.png)

# %% [markdown]
# ###  - PIŁOKSZTAŁTNY
#
# Generowanie wykresu piłokształtnego o zadanej częstotliwości i długości

# %%
import scikit_build_example as az
f = 5
l = 100
az.generate_sawtooth_wave(f, l)

# %% [markdown]
# ![image.png](attachment:a2e85f79-61ce-4b53-bde3-78960263a322.png)

# %% [markdown]
# ###  - PROSTOKĄTNY
#
# Generowanie wykresu prostokątnego o zadanej częstotliwości, długości i

# %%
import scikit_build_example as az
f = 5
l = 100
p = 10
az.generate_square_wave(f, l, p)

# %% [markdown]
# ![image.png](attachment:e24dd86d-9fdd-4b4e-b00c-378ed3bf3423.png)

# %% [markdown]
# ## 3. DFT i transformata odwrotna

# %%
import scikit_build_example as az

# %% [markdown]
# ## 4. Progowanie sygnału (1 dla > progu, 0 dla mniejszego)

# %% [markdown]
# Przykład progowania sygnału dla sygnału audio

# %%
import scikit_build_example as az
az.threshold_signal("C:/ZOSIA/Studia/projekt_sygnaly/examples_test-audio.wav")

# %% [markdown]
# ![image.png](attachment:53b691d9-019c-4129-906a-73ebb2f13894.png)

# %% [markdown]
# Wizualizacja tego sygnału audio

# %%
import scikit_build_example as az
az.visualize_audio("C:/ZOSIA/Studia/projekt_sygnaly/examples_test-audio.wav")

# %% [markdown]
# ![image.png](attachment:0ecf1852-93c6-4243-812e-55a190d1152f.png)
