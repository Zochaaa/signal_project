# %% [markdown]
# # **TECHNIKI PROGRAMOWANIA - PROJEKT 3**
#
#
#
# #### Zofia Narloch,  198232,  ACIR3
# #### Aleksandra Słomska,  198185,  ACIR3

# %% [markdown]
# Wykorzystane biblioteki:
# - matploplusplus (c++)
# - AudioFile (c++)
# - iostream (c++)
# - vextor (c++)
# - complex (c++)
# - cmath (c++)
# - string (c++)
# - pybind11 (c++)
# - numeric (c++)

# %% [markdown]
# ## 1. Wizualizacja sygnału z wykorzystaniem biblioteki matplotplusplus

# %% [markdown]
# Przykład wizualizacji sygnału dla sygnału audio dla 500 pierwszych sampli

# %%
import scikit_build_example as az
az.visualize_audio("C:/ZOSIA/Studia/projekt_sygnaly/examples_test-audio.wav")
# w miejscu przykładowej ścieżki - ścieżka do pliku audio zapisanego lokalnie

# %% [markdown]
# ![image.png](attachment:19808375-0976-40a8-9104-12bedf1aaa18.png)

# %% [markdown]
# ## 2. Generowanie sygnałów o zadanej częstotliwości (sin, cos, prostokątny, piłokształtny)

# %% [markdown]
# ###  - SINUS
#
# Generowanie wykresu sinusa o zadanej częstotliwości

# %%
import scikit_build_example as az
f = 5
az.generate_sine_wave(f)

# %% [markdown]
# ![image.png](attachment:f4a3f071-f00e-4037-ae7f-dc2f39cdb4b7.png)

# %% [markdown]
# ###  - COSINUS
#
# Generowanie wykresu cosinusa o zadanej częstotliwości

# %%
import scikit_build_example as az
f = 5
az.generate_cosine_wave(f)

# %% [markdown]
# ![image.png](attachment:42295f6d-c8b8-4247-ab5f-6ddeb54d660e.png)

# %% [markdown]
# ###  - PIŁOKSZTAŁTNY
#
# Generowanie wykresu piłokształtnego o zadanej częstotliwości i długości

# %%
import scikit_build_example as az
f = 5
l = 100
az.generate_sawtooth_wave(f, l)

# %% [markdown]
# ![image.png](attachment:4a06450b-0e74-4abc-a206-141e1ff61925.png)

# %% [markdown]
# ###  - PROSTOKĄTNY
#
# Generowanie wykresu prostokątnego o zadanej częstotliwości, długości i progu

# %%
import scikit_build_example as az
f = 5
l = 100
az.generate_square_wave(f, l)

# %% [markdown]
# ![image.png](attachment:d5763da1-21d5-4402-af9e-18494c436598.png)

# %% [markdown]
# ## 4. Progowanie sygnału (1 dla > progu, 0 dla mniejszego)

# %% [markdown]
# Przykład progowania sygnału dla sygnału sinusowego

# %%
import scikit_build_example as az
wave = az.generate_sine_wave(10.0)
az.threshold_signal(wave, 0.2)

# %% [markdown]
# Wizualizacja tego sygnału audio

# %% [markdown]
# ![image.png](attachment:de93f657-d52c-440a-8e7d-4eaa47e5871c.png)

# %% [markdown]
# ## 3. DFT i transformata odwrotna

# %% [markdown]
# W celu sprawdzenia poprawności implementacji DFT wykorzystamy wygenerowany sygnał piłokształtny

# %%
import scikit_build_example as az
f = 5
A = 10
sR = 500
nS = 1000
az.dft_idft(f, A, sR, nS)

# %% [markdown]
# Na pierwszym wykresie można zauważyć wygenerowany wykres piłokształtny, na drugim wykresie implementacja dft i na trzecim zastosowana transformata odwrotna

# %% [markdown]
# ![image.png](attachment:593bc9f7-977f-41fe-8db8-ab22fadc2cc7.png)
